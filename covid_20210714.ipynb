# %%
using Blink, Interact, Plots, WebIO, GraphRecipes,CSV,DataFrames, Dates, DynamicalSystems


urli = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
#urld = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
#urlr = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"
download(urli,"covid_infected.csv")
readdir()
#datai = CSV.read("covid_infected_20210712.csv",DataFrame);
datai = CSV.read("covid_infected.csv",DataFrame);
einw = CSV.read("einwohner.csv",DataFrame);
rename!(datai,1 => "province", 2 => "country")
countries = collect(datai[:,2])
provinces = collect(datai[:,1])
contrprov = collect(datai[:,2])
#data_cum = collect(datai[:,5:])
einwl = collect(einw[:,1])
einwz = collect(einw[:,2])
datainc = datai
names_df = names(datai)
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-6437264819252292881\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-13263194464799613708\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-6437264819252292881\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# 544-element Vector{String}:
#  "province"
#  "country"
#  "Lat"
#  "Long"
#  "1/22/20"
#  "1/23/20"
#  "1/24/20"
#  "1/25/20"
#  "1/26/20"
#  "1/27/20"
#  "1/28/20"
#  "1/29/20"
#  "1/30/20"
#  ⋮
#  "7/3/21"
#  "7/4/21"
#  "7/5/21"
#  "7/6/21"
#  "7/7/21"
#  "7/8/21"
#  "7/9/21"
#  "7/10/21"
#  "7/11/21"
#  "7/12/21"
#  "7/13/21"
#  "7/14/21"

# %%
extract_country = "a"
unique_countries = unique(countries)

for i in 1:length(countries)
    if ismissing(provinces[i])
        pro = ""
    else
        pro = " " * provinces[i]
    end
#   contrprov[i] = countries[i]  
    contrprov[i] = countries[i] * pro 
end

numdat = length(collect(datai[1,:]))-4
numcountr = length(unique_countries)

unique_countries_sort_rate = Array{String, 1}(undef,numcountr)
unique_countries_sort_inc = Array{String, 1}(undef,numcountr)
index_uniq = Array{Int, 1}(undef,numcountr)
val_array = Array{Float64, 1}(undef,numdat)
data_extr_unique = Array{Int, 2}(undef,numcountr,numdat)
#@show countries
unique_countries = unique(countries)
#@show unique_countries


#for i in 125:128
for i in 1:numcountr
#    @show unique_countries[i]
    index_all = findall(x -> x==unique_countries[i] , countries)
    lenindall = length(index_all)
#    @show i index_all lenindall
    if lenindall == 1 
        index_uniq[i] = findfirst(x -> x==unique_countries[i] , countries)
    else
#        @show unique_countries[i], index_all
        for j5 = 1:lenindall   
             index_uniq[i] = 0
#              @show countries[index_all[j5]] provinces[index_all[j5]]
            if ismissing(provinces[index_all[j5]])
                index_uniq[i] = index_all[j5]
            end
        end
    end
#    @show i numdat index_uniq[i] unique_countries[i]
    if index_uniq[i] == 0
        for k4 in 1:numdat
          data_extr_unique[i,k4] = 0
#             @show i k4
            for l1 in 1:lenindall
#                @show l1  index_all[l1] datai[index_all[l1],k4+4]
                val_array = collect(datai[index_all[l1],:])
                val = val_array[k4+4]
#               @show  val
                data_extr_unique[i,k4] = data_extr_unique[i,k4] + val
            end
        end
        index_uniq[i] = index_uniq[i-1]+1
#         @show  i index_uniq[i]
    else
      data_extr_unique[i,:] = collect(datai[index_uniq[i],5:end])
    end
end
#@show numcountr numdat data_extr_unique[numcountr,numdat]

data_last_rate= Array{Int, 2}(undef,numcountr,2)
data_sort_rate= Array{Int, 2}(undef,numcountr,2)
data_last_inc= Array{Float64, 1}(undef,numcountr)
data_sort_inc= Array{Float64, 2}(undef,numcountr,2)
#@show numcountr,numdat
#@show  length(data_last_inc)
#@show length(einwz)
#@show  data_extr_unique

for k4 in 1:numcountr
    numdat1 = numdat - 1
#    @show numdat numdat1 data_extr_unique[k4,numdat] data_extr_unique[k4,numdat1]
     data_last_rate[k4,2] = data_extr_unique[k4,numdat] - data_extr_unique[k4,numdat1]
     data_last_rate[k4,1] = index_uniq[k4]

     data_last_inc[k4] = 0
     sum = 0
     for i5 in 1:7
#        @show i5 sum data_extr_unique[k4,numdat+1-i5] data_extr_unique[k4,numdat-i5]
         sum = sum + data_extr_unique[k4,numdat+1-i5] - data_extr_unique[k4,numdat-i5]
     end
#    @show sum
   for i6 in 1:length(einwz) 
      if einwl[i6] ==  unique_countries[k4]  
#        @show k4, unique_countries[k4], i6, einwl[i6], einwz[i6]        
        if einwz[i6] == 0
          data_last_inc[k4] = 0
        else
          
          data_last_inc[k4] = sum/float(einwz[i6])*100000.
        end
#        @show   sum, data_last_inc[k4]
      end
    end
end
#@show data_last_inc
#@show data_last_rate

#data_sort_rate = sort!(data_sort_rate, dims=1, rev=true)
#data_sort_rate = sortslices(data_sort_rate, dims=2)
#A[sortperm(A[:, 4]), :] # sorted by the 4th column



date_names = String.(names(datai[1,5:end]))

numland = length(index_uniq)
date_names
index_uniq
#@show data_last_rate[:,2]
#@show data_last_inc
sortind1 = sortperm(data_last_rate[:,2],rev=true)
sortind2 = sortperm(data_last_inc,rev=true)
#sortind = index_uniq[sortind1]
#@show unique_countries
#@show sortind1
#for i5 in 125:127
#@show numland
for i8 in 1:numland
#    @show i8
    data_sort_rate[i8,1] = sortind1[i8]
    data_sort_rate[i8,2] = data_last_rate[sortind1[i8],2]    
    data_sort_inc[i8,1] = sortind2[i8]
    data_sort_inc[i8,2] = data_last_inc[sortind2[i8]]
    unique_countries_sort_rate[i8] =  unique_countries[sortind1[i8]]
    unique_countries_sort_inc[i8] =  unique_countries[sortind2[i8]]
end



#length(unique_countries)

#data_sort_rate
#unique_countries_sort;
#sortind2
#data_sort_inc
unique_countries_sort_inc
# Out:
# 195-element Vector{String}:
#  "Seychelles"
#  "Cyprus"
#  "Tunisia"
#  "Fiji"
#  "Mongolia"
#  "United Kingdom"
#  "Cuba"
#  "Namibia"
#  "Netherlands"
#  "Spain"
#  "Colombia"
#  "Kuwait"
#  "Botswana"
#  ⋮
#  "Palau"
#  "Saint Kitts and Nevis"
#  "Saint Lucia"
#  "Saint Vincent and the Grenadines"
#  "Samoa"
#  "Solomon Islands"
#  "Sudan"
#  "Summer Olympics 2020"
#  "Taiwan*"
#  "Tanzania"
#  "Vanuatu"
#  "West Bank and Gaza"

# %%
function create_plots(i,countr,dict1)
@show dict1, i,countr  

if dict1 == 0
#    index = index_uniq[i]
    index = i
else
    if dict1 == 1
        index = sortind1[i]
    else
        index = sortind2[i]
    end
end
extract_country = countr
#extract_country = xx[2]
    
@show extract_country      



index_einw = findfirst(x -> x==extract_country , einwl)
einwz[index_einw]
    
data_extr = data_extr_unique[index,:]
countryname =  unique_countries[index]
lendat = length(data_extr)
@show lendat  
    
if data_extr[1] <= 0
        data_extr[1] = 1
end
for i1 in 2:lendat
    if data_extr[i1] <= 0
        data_extr[i1] = data_extr[i1-1]
    end
end
#    @show data_extr  

data_extr_rate = Array{Int, 1}(undef,lendat)
data_incidence = Array{Float64, 1}(undef,lendat) 
data_extr_avg = Array{Float64, 1}(undef,lendat)
data_extr_rate[1] = 0
for i2 in 2:lendat
    data_extr_rate[i2] = data_extr[i2] - data_extr[i2-1]
    if data_extr_rate[i2] < 0
        data_extr_rate[i2] = 1
    end
#    @show i2 data_extr_rate[i2] data_extr[i2] data_extr[i2-1]
end
# @show data_extr_rate
#@show index_einw, einwz[index_einw]
for i3 in 1:6
    data_extr_avg[i3] = 0
    data_incidence[i3] = 0
end
for i4 in 7:lendat
    sum = 0
    for i5 in 1:7
        sum = sum + data_extr_rate[i4-i5+1]
    end
    if einwz[index_einw] == 0
            data_incidence[i4] = 0
        else
            data_incidence[i4] = sum/einwz[index_einw]*100000.
        end
    sum = sum/7
    data_extr_avg[i4] = sum
end
# @show data_incidence

dates = date_names
#dfinc =  DataFrame(land=contrprov, inc=data_incidence)


#@manipulate for i in 1:length(data_extr)
#  HTML(data_extr[i])
#end
#findall.(extr_country,contrprov)
#findall(occursin.(query,contrprov))
format = Dates.DateFormat("m/d/YY")
datesplot = parse.(Date,dates,format).+Year(2000)
p1=plot(datesplot,data_extr_rate,xticks=datesplot[1:90:end], leg=:topleft, 
#p1=plot(datesplot,data_sort_rate,xticks=datesplot[1:90:end], leg=:topleft, 
        label=string(extract_country)*": "*string(data_extr_rate[end]), ylim=(0.,),
        title="Bestätigte COVID-Infektionen",ylabel="COVID-Infektionen pro Tag",
        color = :lightgreen,fill = (0, 0.5, :lightgreen))
p2=plot!(datesplot,data_extr_avg,label="7-Tage-Mittel", ylim=(0.,),color = :black,linewidth = 2)
  inz =  round.(Int,data_incidence[numdat])
p3=plot(datesplot,data_incidence,xticks=datesplot[1:90:end],label="Inzidenz: "*string(inz),
    leg=:topleft,title="Inzidenz "*string(extract_country),ylabel="Inzidenz",
            color=:blue,fill = (0, 0.5, :red),linewidth = 2,background_color = :ivory)


    
plot(p1,p3,layout=(2,1),size=(750, 450))
    
#background_color{RGB(0,5;)}
#button("sort")
#xlabel!("Datum")
#ylabel!("COVID-Infektionen pro Tag")
#plotattr(:Series)
#plotattr(:Subplot)
#plotattr(:Axis)
#plotattr("background_color")    
#plotattr(:Plot)
#background_color, background_color_outside, display_type, dpi, extra_kwargs, extra_plot_kwargs, fontfamily, foreground_color, html_output_format, inset_subplots, layout, link, overwrite_figure, plot_title, plot_title_location, plot_titlefontcolor, plot_titlefontfamily, plot_titlefonthalign, plot_titlefontrotation, plot_titlefontsize, plot_titlefontvalign, pos, show, size, tex_output_standalone, thickness_scaling, warn_on_unsupported, window_title
end
# Out:
# create_plots (generic function with 1 method)

# %%
#sort_auswahl = 0
#s = @manipulate throttle=1.0 for i in 1:length(unique_countries)
 s = @manipulate for i=slider(1:length(unique_countries), value=1), 
    sort_auswahl= Dict("sort Inzidenz" => 2, "sort Tagesänderung" => 1,"no sort" => 0 )
#    i,contrprov[i]
    #@manipulate for i=slider(1:10, value=3)

#    i
#    println(i,contrprov[i])
   
    @show sort_auswahl
#    @show unique_countries_sort
    if sort_auswahl == 0
        create_plots(i,unique_countries[i],sort_auswahl)
    else
        if sort_auswahl == 1
           create_plots(i,unique_countries_sort_rate[i],sort_auswahl)
        else
            @show i, sort_auswahl, unique_countries_sort_inc[i]
           create_plots(i,unique_countries_sort_inc[i],sort_auswahl)
        end       
    end
end
   w = Window()
   body!(w,s)
#@manipulate for i=slider(1:10, value=3)
#   i
#end    
#@manipulate for i in 1:length(data_extr)
#  HTML(data_extr[i])
#end
# Out:
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (1, 2, "Seychelles")
# (dict1, i, countr) = (2, 1, "Seychelles")
# extract_country = "Seychelles"
# lendat = 540
# Page(1, WebSocket(server, CONNECTED), Dict{String, Any}("webio" => Blink.AtomShell.var"#24#25"{Blink.AtomShell.WebIOBlinkComm}(Blink.AtomShell.WebIOBlinkComm(Window(1, Electron(Process(`/Users/gg/.julia/packages/Blink/mwJC9/deps/Julia.app/Contents/MacOS/Julia /Users/gg/.julia/packages/Blink/mwJC9/src/AtomShell/main.js port 3597`, ProcessRunning), Sockets.TCPSocket(RawFD(53) active, 0 bytes waiting), Dict{String, Any}("callback" => Blink.var"#1#2"())), Page(#= circular reference @-5 =#), Task (done) @0x00000001338b0ab0))), "callback" => Blink.var"#1#2"()), Distributed.Future(1, 1, 1, Some(true)))
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (2, 2, "Cyprus")
# (dict1, i, countr) = (2, 2, "Cyprus")
# extract_country = "Cyprus"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (3, 2, "Tunisia")
# (dict1, i, countr) = (2, 3, "Tunisia")
# extract_country = "Tunisia"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (4, 2, "Fiji")
# (dict1, i, countr) = (2, 4, "Fiji")
# extract_country = "Fiji"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (5, 2, "Mongolia")
# (dict1, i, countr) = (2, 5, "Mongolia")
# extract_country = "Mongolia"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (6, 2, "United Kingdom")
# (dict1, i, countr) = (2, 6, "United Kingdom")
# extract_country = "United Kingdom"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (7, 2, "Cuba")
# (dict1, i, countr) = (2, 7, "Cuba")
# extract_country = "Cuba"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (8, 2, "Namibia")
# (dict1, i, countr) = (2, 8, "Namibia")
# extract_country = "Namibia"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (9, 2, "Netherlands")
# (dict1, i, countr) = (2, 9, "Netherlands")
# extract_country = "Netherlands"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (10, 2, "Spain")
# (dict1, i, countr) = (2, 10, "Spain")
# extract_country = "Spain"
# lendat = 540
# sort_auswahl = 2
# (i, sort_auswahl, unique_countries_sort_inc[i]) = (11, 2, "Colombia")
# (dict1, i, countr) = (2, 11, "Colombia")
# extract_country = "Colombia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 11, "Azerbaijan")
# extract_country = "Azerbaijan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 13, "Bahrain")
# extract_country = "Bahrain"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 15, "Barbados")
# extract_country = "Barbados"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 17, "Belgium")
# extract_country = "Belgium"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 20, "Bhutan")
# extract_country = "Bhutan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 24, "Brazil")
# extract_country = "Brazil"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 28, "Burma")
# extract_country = "Burma"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 31, "Cambodia")
# extract_country = "Cambodia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 33, "Canada")
# extract_country = "Canada"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 35, "Chad")
# extract_country = "Chad"
# ArgumentError: invalid index: nothing of type Nothing
# Stacktrace:
#   [1] to_index(i::Nothing)
#     @ Base ./indices.jl:300
#   [2] to_index(A::Vector{Int64}, i::Nothing)
#     @ Base ./indices.jl:277
#   [3] to_indices
#     @ ./indices.jl:333 [inlined]
#   [4] to_indices
#     @ ./indices.jl:325 [inlined]
#   [5] getindex(A::Vector{Int64}, I::Nothing)
#     @ Base ./abstractarray.jl:1170
#   [6] create_plots(i::Int64, countr::String, dict1::Int64)
#     @ Main ./In[13]:22
#   [7]
# sort_auswahl = 0
# (dict1, i, countr) = (0, 37, "China")
# extract_country = "China"
# lendat = 540
# sort_auswahl = 0
# (::var"#31#32")(i::Int64, sort_auswahl::Int64)
#     @ Main ./In[14]:14
#   [8] (::Observables.MapUpdater{var"#31#32", Any})(::Int64, ::Vararg{Int64, N} where N)
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:331
#   [9] (::Observables.OnUpdate{Observables.MapUpdater{var"#31#32", Any}, Tuple{Widget{:slider, Int64}, Widget{:togglebuttons, Any}}})(#unused#::Int64)
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:298
#  [10] setindex!(observable::Observable{Int64}, val::Int64; notify::WebIO.var"#44#45")
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:205
#  [11] setexcludinghandlers
#     @ ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:260 [inlined]
#  [12] set_nosync(ob::Observable{Int64}, val::Int64)
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/scope.jl:339
#  [13] dispatch(ctx::Scope, key::String, data::Int64)
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/scope.jl:348
#  [14] dispatch_command(conn::Blink.AtomShell.WebIOBlinkComm, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/messaging.jl:104
#  [15] dispatch(conn::Blink.AtomShell.WebIOBlinkComm, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/messaging.jl:81
#  [16] (::Blink.AtomShell.var"#24#25"{Blink.AtomShell.WebIOBlinkComm})(msg::Dict{String, Any})
#     @ Blink.AtomShell ~/.julia/packages/Blink/mwJC9/src/AtomShell/webio.jl:24
#  [17] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [18] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [19] handle_message(o::Page, m::Dict{String, Any})
#     @ Blink ~/.julia/packages/Blink/mwJC9/src/rpc/callbacks.jl:7
#  [20] macro expansion
#     @ ~/.julia/packages/Lazy/9Xnd3/src/macros.jl:268 [inlined]
#  [21] ws_handler(req::Dict{Any, Any})
#     @ Blink ~/.julia/packages/Blink/mwJC9/src/content/server.jl:56
#  [22] splitquery(app::typeof(Blink.ws_handler), req::Dict{Any, Any})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/basics.jl:31
#  [23] #1
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10 [inlined]
#  [24] wcatch(app::Mux.var"#1#2"{typeof(Mux.splitquery), typeof(Blink.ws_handler)}, req::Dict{Any, Any})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/websockets_integration.jl:12
#  [25] #1
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10 [inlined]
#  [26] todict
#     @ ~/.julia/packages/Mux/3h8RY/src/basics.jl:25 [inlined]
#  [27] #3 (repeats 2 times)
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:14 [inlined]
#  [28] (::Mux.var"#1#2"{Mux.var"#3#4"{Mux.var"#3#4"{typeof(Mux.todict), typeof(Mux.wcatch)}, typeof(Mux.splitquery)}, typeof(Blink.ws_handler)})(x::Tuple{HTTP.Messages.Request, WebSockets.WebSocket{Sockets.TCPSocket}})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10
#  [29] (::Mux.var"#9#10"{Mux.App})(req::HTTP.Messages.Request, client::WebSockets.WebSocket{Sockets.TCPSocket})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/server.jl:49
#  [30] upgrade(f::Mux.var"#9#10"{Mux.App}, stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}})
#     @ WebSockets ~/.julia/packages/WebSockets/QcswW/src/HTTP.jl:201
#  [31] (::WebSockets.var"#_servercoroutine#11"{WebSockets.ServerWS})(stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}})
#     @ WebSockets ~/.julia/packages/WebSockets/QcswW/src/HTTP.jl:370
#  [32] macro expansion
#     @ ~/.julia/packages/HTTP/4AvE2/src/Servers.jl:413 [inlined]
#  [33] (::HTTP.Servers.var"#13#14"{WebSockets.var"#_servercoroutine#11"{WebSockets.ServerWS}, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}, HTTP.Servers.Server{Nothing, Sockets.TCPServer}, HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}}})()
#     @ HTTP.Servers ./task.jl:411
# (dict1, i, countr) = (0, 40, "Congo (Brazzaville)")
# extract_country = "Congo (Brazzaville)"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 41, "Congo (Kinshasa)")
# extract_country = "Congo (Kinshasa)"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 42, "Costa Rica")
# extract_country = "Costa Rica"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 43, "Cote d'Ivoire")
# extract_country = "Cote d'Ivoire"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 45, "Cuba")
# extract_country = "Cuba"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 47, "Czechia")
# extract_country = "Czechia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 48, "Denmark")
# extract_country = "Denmark"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 50, "Djibouti")
# extract_country = "Djibouti"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 52, "Dominican Republic")
# extract_country = "Dominican Republic"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 54, "Egypt")
# extract_country = "Egypt"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 55, "El Salvador")
# extract_country = "El Salvador"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 58, "Estonia")
# extract_country = "Estonia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 60, "Ethiopia")
# extract_country = "Ethiopia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 62, "Finland")
# extract_country = "Finland"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 64, "Gabon")
# extract_country = "Gabon"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 66, "Georgia")
# extract_country = "Georgia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 67, "Germany")
# extract_country = "Germany"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 69, "Greece")
# extract_country = "Greece"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 71, "Guatemala")
# extract_country = "Guatemala"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 72, "Guinea")
# extract_country = "Guinea"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 73, "Guinea-Bissau")
# extract_country = "Guinea-Bissau"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 74, "Guyana")
# extract_country = "Guyana"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 76, "Holy See")
# extract_country = "Holy See"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 78, "Hungary")
# extract_country = "Hungary"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 79, "Iceland")
# extract_country = "Iceland"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 81, "Indonesia")
# extract_country = "Indonesia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 82, "Iran")
# extract_country = "Iran"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 84, "Ireland")
# extract_country = "Ireland"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 85, "Israel")
# extract_country = "Israel"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 86, "Italy")
# extract_country = "Italy"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 88, "Japan")
# extract_country = "Japan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 89, "Jordan")
# extract_country = "Jordan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 90, "Kazakhstan")
# extract_country = "Kazakhstan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 91, "Kenya")
# extract_country = "Kenya"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 92, "Kiribati")
# extract_country = "Kiribati"
# sort_auswahl = 0
# (dict1, i, countr) = (0, 93, "Korea, South")
# extract_country = "Korea, South"
# lendat = 540
# sort_auswahl = 0
# ArgumentError: invalid index: nothing of type Nothing
# Stacktrace:
#   [1] to_index(i::Nothing)
#     @ Base ./indices.jl:300
#   [2] to_index(A::Vector{Int64}, i::Nothing)
#     @ Base ./indices.jl:277
#   [3] to_indices
#     @ ./indices.jl:333 [inlined]
#   [4] to_indices
#     @ ./indices.jl:325 [inlined]
#   [5] getindex(A::Vector{Int64}, I::Nothing)
#     @ Base ./abstractarray.jl:1170
#   [6] create_plots(i::Int64, countr::String, dict1::Int64)
#     @ Main ./In[13]:22
#   [7] (::var"#31#32")(i::Int64, sort_auswahl::Int64)
#     @ Main ./In[14]:14
#   [8] (::Observables.MapUpdater{var"#31#32", Any})(::Int64, ::Vararg{Int64, N} where N)
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:331
#   [9] (::Observables.OnUpdate{Observables.MapUpdater{var"#31#32", Any}, Tuple{Widget{:slider, Int64}, Widget{:togglebuttons, Any}}})(#unused#::Int64)
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:298
#  [10] setindex!(observable::Observable{Int64}, val::Int64; notify::WebIO.var"#44#45")
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:205
#  [11] setexcludinghandlers
#     @ ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:260 [inlined]
#  [12] set_nosync(ob::Observable{Int64}, val::Int64)
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/scope.jl:339
#  [13] dispatch(ctx::Scope, key::String, data::Int64)
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/scope.jl:348
#  [14] dispatch_command(conn::Blink.AtomShell.WebIOBlinkComm, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/messaging.jl:104
#  [15] dispatch(conn::Blink.AtomShell.WebIOBlinkComm, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/messaging.jl:81
#  [16] (::Blink.AtomShell.var"#24#25"{Blink.AtomShell.WebIOBlinkComm})(msg::Dict{String, Any})
#     @ Blink.AtomShell ~/.julia/packages/Blink/mwJC9/src/AtomShell/webio.jl:24
#  [17] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [18] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [19] handle_message(o::Page, m::Dict{String, Any})
#     @ Blink ~/.julia/packages/Blink/mwJC9/src/rpc/callbacks.jl:7
#  [20] macro expansion
#     @ ~/.julia/packages/Lazy/9Xnd3/src/macros.jl:268 [inlined]
#  [21] ws_handler(req::Dict{Any, Any})
#     @ Blink ~/.julia/packages/Blink/mwJC9/src/content/server.jl:56
#  [22] splitquery(app::typeof(Blink.ws_handler), req::Dict{Any, Any})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/basics.jl:31
#  [23] #1
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10 [inlined]
#  [24] wcatch(app::Mux.var"#1#2"{typeof(Mux.splitquery), typeof(Blink.ws_handler)}, req::Dict{Any, Any})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/websockets_integration.jl:12
#  [25] #1
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10 [inlined]
#  [26] todict
#     @ ~/.julia/packages/Mux/3h8RY/src/basics.jl:25 [inlined]
#  [27] #3 (repeats 2 times)
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:14 [inlined]
#  [28] (::Mux.var"#1#2"{Mux.var"#3#4"{Mux.var"#3#4"{typeof(Mux.todict), typeof(Mux.wcatch)}, typeof(Mux.splitquery)}, typeof(Blink.ws_handler)})(x::Tuple{HTTP.Messages.Request, WebSockets.WebSocket{Sockets.TCPSocket}})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10
#  [29] (::Mux.var"#9#10"{Mux.App})(req::HTTP.Messages.Request, client::WebSockets.WebSocket{Sockets.TCPSocket})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/server.jl:49
#  [30] upgrade(f::Mux.var"#9#10"{Mux.App}, stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}})
#     @ WebSockets ~/.julia/packages/WebSockets/QcswW/src/HTTP.jl:201
#  [31] (::WebSockets.var"#_servercoroutine#11"{WebSockets.ServerWS})(stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}})
#     @ WebSockets ~/.julia/packages/WebSockets/QcswW/src/HTTP.jl:370
#  [32] macro expansion
#     @ ~/.julia/packages/HTTP/4AvE2/src/Servers.jl:413 [inlined]
#  [33] (::HTTP.Servers.var"#13#14"{WebSockets.var"#_servercoroutine#11"{WebSockets.ServerWS}, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}, HTTP.Servers.Server{Nothing, Sockets.TCPServer}, HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}}})()
#     @ HTTP.Servers ./task.jl:411
# (dict1, i, countr) = (0, 94, "Kosovo")
# extract_country = "Kosovo"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 93, "Korea, South")
# extract_country = "Korea, South"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 92, "Kiribati")
# extract_country = "Kiribati"
# sort_auswahl = 0
# (dict1, i, countr) = (0, 90, "Kazakhstan")
# extract_country = "Kazakhstan"
# lendat = 540
# sort_auswahl = 0
# ArgumentError: invalid index: nothing of type Nothing
# Stacktrace:
#   [1] to_index(i::Nothing)
#     @ Base ./indices.jl:300
#   [2] to_index(A::Vector{Int64}, i::Nothing)
#     @ Base ./indices.jl:277
#   [3] to_indices
#     @ ./indices.jl:333 [inlined]
#   [4] to_indices
#     @ ./indices.jl:325 [inlined]
#   [5] getindex(A::Vector{Int64}, I::Nothing)
#     @ Base ./abstractarray.jl:1170
#   [6] create_plots(i::Int64, countr::String, dict1::Int64)
#     @ Main ./In[13]:22
#   [7] (::var"#31#32")(i::Int64, sort_auswahl::Int64)
#     @ Main ./In[14]:14
#   [8] (::Observables.MapUpdater{var"#31#32", Any})(::Int64, ::Vararg{Int64, N} where N)
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:331
#   [9] (::Observables.OnUpdate{Observables.MapUpdater{var"#31#32", Any}, Tuple{Widget{:slider, Int64}, Widget{:togglebuttons, Any}}})(#unused#::Int64)
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:298
#  [10] setindex!(observable::Observable{Int64}, val::Int64; notify::WebIO.var"#44#45")
#     @ Observables ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:205
#  [11] setexcludinghandlers
#     @ ~/.julia/packages/Observables/Yf3xU/src/Observables.jl:260 [inlined]
#  [12] set_nosync(ob::Observable{Int64}, val::Int64)
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/scope.jl:339
#  [13] dispatch(ctx::Scope, key::String, data::Int64)
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/scope.jl:348
#  [14] dispatch_command(conn::Blink.AtomShell.WebIOBlinkComm, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/messaging.jl:104
#  [15] dispatch(conn::Blink.AtomShell.WebIOBlinkComm, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/Fy9h1/src/messaging.jl:81
#  [16] (::Blink.AtomShell.var"#24#25"{Blink.AtomShell.WebIOBlinkComm})(msg::Dict{String, Any})
#     @ Blink.AtomShell ~/.julia/packages/Blink/mwJC9/src/AtomShell/webio.jl:24
#  [17] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [18] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [19] handle_message(o::Page, m::Dict{String, Any})
#     @ Blink ~/.julia/packages/Blink/mwJC9/src/rpc/callbacks.jl:7
#  [20] macro expansion
#     @ ~/.julia/packages/Lazy/9Xnd3/src/macros.jl:268 [inlined]
#  [21] ws_handler(req::Dict{Any, Any})
#     @ Blink ~/.julia/packages/Blink/mwJC9/src/content/server.jl:56
#  [22] splitquery(app::typeof(Blink.ws_handler), req::Dict{Any, Any})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/basics.jl:31
#  [23] #1
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10 [inlined]
#  [24] wcatch(app::Mux.var"#1#2"{typeof(Mux.splitquery), typeof(Blink.ws_handler)}, req::Dict{Any, Any})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/websockets_integration.jl:12
#  [25] #1
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10 [inlined]
#  [26] todict
#     @ ~/.julia/packages/Mux/3h8RY/src/basics.jl:25 [inlined]
#  [27] #3 (repeats 2 times)
#     @ ~/.julia/packages/Mux/3h8RY/src/Mux.jl:14 [inlined]
#  [28] (::Mux.var"#1#2"{Mux.var"#3#4"{Mux.var"#3#4"{typeof(Mux.todict), typeof(Mux.wcatch)}, typeof(Mux.splitquery)}, typeof(Blink.ws_handler)})(x::Tuple{HTTP.Messages.Request, WebSockets.WebSocket{Sockets.TCPSocket}})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/Mux.jl:10
#  [29] (::Mux.var"#9#10"{Mux.App})(req::HTTP.Messages.Request, client::WebSockets.WebSocket{Sockets.TCPSocket})
#     @ Mux ~/.julia/packages/Mux/3h8RY/src/server.jl:49
#  [30] upgrade(f::Mux.var"#9#10"{Mux.App}, stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}})
#     @ WebSockets ~/.julia/packages/WebSockets/QcswW/src/HTTP.jl:201
#  [31] (::WebSockets.var"#_servercoroutine#11"{WebSockets.ServerWS})(stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}})
#     @ WebSockets ~/.julia/packages/WebSockets/QcswW/src/HTTP.jl:370
#  [32] macro expansion
#     @ ~/.julia/packages/HTTP/4AvE2/src/Servers.jl:413 [inlined]
#  [33] (::HTTP.Servers.var"#13#14"{WebSockets.var"#_servercoroutine#11"{WebSockets.ServerWS}, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}, HTTP.Servers.Server{Nothing, Sockets.TCPServer}, HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Transaction{Sockets.TCPSocket}}})()
#     @ HTTP.Servers ./task.jl:411
# (dict1, i, countr) = (0, 89, "Jordan")
# extract_country = "Jordan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 88, "Japan")
# extract_country = "Japan"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 86, "Italy")
# extract_country = "Italy"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 85, "Israel")
# extract_country = "Israel"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 84, "Ireland")
# extract_country = "Ireland"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 83, "Iraq")
# extract_country = "Iraq"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 82, "Iran")
# extract_country = "Iran"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 81, "Indonesia")
# extract_country = "Indonesia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 80, "India")
# extract_country = "India"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 79, "Iceland")
# extract_country = "Iceland"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 78, "Hungary")
# extract_country = "Hungary"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 77, "Honduras")
# extract_country = "Honduras"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 76, "Holy See")
# extract_country = "Holy See"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 75, "Haiti")
# extract_country = "Haiti"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 74, "Guyana")
# extract_country = "Guyana"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 73, "Guinea-Bissau")
# extract_country = "Guinea-Bissau"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 72, "Guinea")
# extract_country = "Guinea"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 71, "Guatemala")
# extract_country = "Guatemala"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 70, "Grenada")
# extract_country = "Grenada"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 69, "Greece")
# extract_country = "Greece"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 68, "Ghana")
# extract_country = "Ghana"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 67, "Germany")
# extract_country = "Germany"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 66, "Georgia")
# extract_country = "Georgia"
# lendat = 540
# sort_auswahl = 0
# (dict1, i, countr) = (0, 67, "Germany")
# extract_country = "Germany"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 67, "Israel")
# extract_country = "Israel"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 66, "Namibia")
# extract_country = "Namibia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 64, "Jordan")
# extract_country = "Jordan"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 62, "Malawi")
# extract_country = "Malawi"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 59, "Cambodia")
# extract_country = "Cambodia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 55, "Oman")
# extract_country = "Oman"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 49, "Honduras")
# extract_country = "Honduras"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 45, "United Arab Emirates")
# extract_country = "United Arab Emirates"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 40, "Germany")
# extract_country = "Germany"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 35, "Nepal")
# extract_country = "Nepal"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 33, "Morocco")
# extract_country = "Morocco"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 31, "Peru")
# extract_country = "Peru"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 30, "Pakistan")
# extract_country = "Pakistan"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 28, "Vietnam")
# extract_country = "Vietnam"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 27, "Guatemala")
# extract_country = "Guatemala"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 26, "Greece")
# extract_country = "Greece"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 25, "Zimbabwe")
# extract_country = "Zimbabwe"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 24, "Japan")
# extract_country = "Japan"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 23, "Philippines")
# extract_country = "Philippines"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 22, "Portugal")
# extract_country = "Portugal"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 20, "Turkey")
# extract_country = "Turkey"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 19, "Burma")
# extract_country = "Burma"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 18, "Tunisia")
# extract_country = "Tunisia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 17, "Thailand")
# extract_country = "Thailand"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 16, "Iraq")
# extract_country = "Iraq"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 15, "Netherlands")
# extract_country = "Netherlands"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 14, "Malaysia")
# extract_country = "Malaysia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 13, "Mexico")
# extract_country = "Mexico"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 12, "Bangladesh")
# extract_country = "Bangladesh"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 11, "Colombia")
# extract_country = "Colombia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 10, "South Africa")
# extract_country = "South Africa"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 9, "Argentina")
# extract_country = "Argentina"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 8, "Russia")
# extract_country = "Russia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 7, "Iran")
# extract_country = "Iran"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 6, "Spain")
# extract_country = "Spain"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 5, "US")
# extract_country = "US"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 4, "India")
# extract_country = "India"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 3, "United Kingdom")
# extract_country = "United Kingdom"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 2, "Indonesia")
# extract_country = "Indonesia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 1, "Brazil")
# extract_country = "Brazil"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 2, "Indonesia")
# extract_country = "Indonesia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 3, "United Kingdom")
# extract_country = "United Kingdom"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 4, "India")
# extract_country = "India"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 5, "US")
# extract_country = "US"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 6, "Spain")
# extract_country = "Spain"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 7, "Iran")
# extract_country = "Iran"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 8, "Russia")
# extract_country = "Russia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 9, "Argentina")
# extract_country = "Argentina"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 10, "South Africa")
# extract_country = "South Africa"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 11, "Colombia")
# extract_country = "Colombia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 12, "Bangladesh")
# extract_country = "Bangladesh"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 13, "Mexico")
# extract_country = "Mexico"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 14, "Malaysia")
# extract_country = "Malaysia"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 15, "Netherlands")
# extract_country = "Netherlands"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 16, "Iraq")
# extract_country = "Iraq"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 17, "Thailand")
# extract_country = "Thailand"
# lendat = 540
# sort_auswahl = 1
# (dict1, i, countr) = (1, 18, "Tunisia")
# extract_country = "Tunisia"
# lendat = 540

# %% [markdown]
# s[]
